# %%
from sympy import *
from sympy.plotting import plot
import math
init_printing()
x=Symbol('x')
a=-12
b=-18
c=5
d=10
f=-30
g=a*x**4+b*x**3+c*x**2 + d*x +f
g
# Out:
#       4       3      2
# - 12⋅x  - 18⋅x  + 5⋅x  + 10⋅x - 30

# %%
p=plot (g,(x,20,-20))

# %%
solve(g)
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢              _______________________________________________________________
# ⎢             ╱                                                _______________
# ⎢            ╱  121                 4885                      ╱ 208045   5⋅√90
# ⎢           ╱   ─── + ──────────────────────────────── + 2⋅3 ╱  ────── + ─────
# ⎢          ╱    144            _______________________     ╲╱   373248      20
# ⎢         ╱                   ╱ 208045   5⋅√9048041⋅ⅈ
# ⎢        ╱            2592⋅3 ╱  ────── + ────────────
# ⎢  3   ╲╱                  ╲╱   373248      20736
# ⎢- ─ - ───────────────────────────────────────────────────────────────────────
# ⎣  8                                          2
#
#                         ______________________________________________________
#                        ╱             _______________________
#                       ╱  121        ╱ 208045   5⋅√9048041⋅ⅈ
# ...

# %%
top = diff(g)
top
# Out:
#       3       2
# - 48⋅x  - 54⋅x  + 10⋅x + 10

# %%
solve(top)[0]
# Out:
#                        __________________
#   3   ⎛  1   √3⋅ⅈ⎞    ╱  19    √108895⋅ⅈ                      121
# - ─ + ⎜- ─ - ────⎟⋅3 ╱  ──── + ─────────  + ──────────────────────────────────
#   8   ⎝  2    2  ⎠ ╲╱   1536      3456                           _____________
#                                                 ⎛  1   √3⋅ⅈ⎞    ╱  19    √1088
#                                             576⋅⎜- ─ - ────⎟⋅3 ╱  ──── + ─────
#                                                 ⎝  2    2  ⎠ ╲╱   1536      34
#
#
#
# ─────
# _____
# 95⋅ⅈ
# ────
# 56

# %%
solve(top>0)
# Out:
# ⎛                    ⎛    3       2             ⎞⎞   ⎛           ⎛    3
# ⎝-∞ < x ∧ x < CRootOf⎝24⋅x  + 27⋅x  - 5⋅x - 5, 0⎠⎠ ∨ ⎝x < CRootOf⎝24⋅x  + 27⋅x
#
# 2             ⎞          ⎛    3       2             ⎞    ⎞
#   - 5⋅x - 5, 2⎠ ∧ CRootOf⎝24⋅x  + 27⋅x  - 5⋅x - 5, 1⎠ < x⎠

# %%
solve(top<0)
# Out:
# ⎛               ⎛    3       2             ⎞    ⎞   ⎛           ⎛    3       2
# ⎝x < ∞ ∧ CRootOf⎝24⋅x  + 27⋅x  - 5⋅x - 5, 2⎠ < x⎠ ∨ ⎝x < CRootOf⎝24⋅x  + 27⋅x
#
#              ⎞          ⎛    3       2             ⎞    ⎞
#  - 5⋅x - 5, 1⎠ ∧ CRootOf⎝24⋅x  + 27⋅x  - 5⋅x - 5, 0⎠ < x⎠

# %%
solve(g>0)
# Out:
# False

# %%
solve(g<0)
# Out:
# -∞ < x ∧ x < ∞
